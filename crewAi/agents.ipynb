# %%
# !pip install crewai crewai-tools
# !pip install crewai
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached crewai_tools-0.73.1-py3-none-any.whl.metadata (11 kB)
# ...
#   Using cached chromadb-0.5.23-py3-none-any.whl.metadata (6.8 kB)
# ...
#   Using cached docker-7.1.0-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached lancedb-0.25.0-cp39-abi3-win_amd64.whl.metadata (4.8 kB)
# ...
#   Using cached pypdf-6.1.0-py3-none-any.whl.metadata (7.1 kB)
# ...
#   Using cached python_docx-1.2.0-py3-none-any.whl.metadata (2.0 kB)
# ...
#   Using cached pytube-15.0.0-py3-none-any.whl.metadata (5.0 kB)
# ...
#   Using cached stagehand-0.5.3-py3-none-any.whl.metadata (9.1 kB)
# ...
#   Using cached youtube_transcript_api-1.2.2-py3-none-any.whl.metadata (24 kB)
# ...
#   Using cached chroma_hnswlib-0.7.6.tar.gz (32 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
# ...

# %%
import os
os.environ["GEMINI_API_KEY"] = ""

# %%
from crewai import LLM

llm = LLM(
    model="gemini/gemini-2.0-flash",
    temperature=0.1,
    api_key=os.environ["GEMINI_API_KEY"]
)

print(llm.call("What is CrewAI?"))
# Out:
# CrewAI is a framework designed to orchestrate autonomous AI agents to work together towards a common goal. Think of it as a platform for building teams of AI workers, each with specific roles, responsibilities, and tools, that can collaborate to solve complex problems.
#
# Here's a breakdown of what makes CrewAI significant:
#
# *   **Agent-Based Architecture:** It allows you to define individual AI agents, each with:
#     *   **Role:** A specific job or function within the crew (e.g., Researcher, Writer, Programmer).
#     *   **Goal:** What the agent is trying to achieve.
#     *   **Backstory:** A narrative to guide the agent's behavior and decision-making.
#     *   **Tools:** Access to specific tools or resources (e.g., search engines, APIs, code interpreters) to help them perform their tasks.
#     *   **LLM (Large Language Model):** The underlying language model that powers the agent's reasoning and communication (e.g., GPT-4, Gemini).
#
# ...

# %%
from crewai import Agent, Task, Crew

email_assistant = Agent(
    role="Email Assistant Agent",
    goal="Improve emails and make them sound professional and clear",
    backstory="A highly experienced communication expert skilled in professional email writing",
    verbose=True,#detail info or output about execution of a program
    llm=llm
)

original_email=""" 
hi,  
r u free now??? i need some help asap. btw can u send me that file again idk where i saved it.  
thanks :)  

"""

# %%
email_task=Task(
    description=f"""take the following rough email and rewrite it into a professional and polished version
    expand abbreviations '''{original_email}'''""",
    agent=email_assistant,
    expected_output="A professional written email with proper formatting and content"
)

# %%
crew=Crew(
    agents=[email_assistant],
    tasks=[email_task],
    verbose=True,
)

# %%
result=crew.kickoff()
print(result)
# Out:
# ╭──────────────────────────────────────────── Crew Execution Started ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: 7aa07855-69cc-4267-ba18-74664f9e1c02                                                                       │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ...
